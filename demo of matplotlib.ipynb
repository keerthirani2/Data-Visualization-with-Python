# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot(6,9,'*')
plt.show()

# %%
#we use the matplotlib notbook for lableing the x and y values after plotting the graph
# %matplotlib notebook

# %%
plt.plot(8,6,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('items')
plt.ylabel('price')
plt.title('prices of items')
plt.show()

# %%
#we can aslo use the pandas functions for the plotting, for the whole data set using  the function kindline
#lets take a sample data
Data = pd.DataFrame({"Items":[5,8,6,4],"Price":[56,89,76,35]})
Data
# Out:
#    Items  Price
# 0      5     56
# 1      8     89
# 2      6     76
# 3      4     35

# %%
Data.plot(kind="line")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
Data.plot.scatter(x="Items",y='Price')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Items', ylabel='Price'>
